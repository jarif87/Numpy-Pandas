# %%
import pandas as pd

# %%
df=pd.read_csv("E:/Download/uberdrive.csv")

# %%
df.head()
# Out:
#       START_DATE*       END_DATE* CATEGORY*       START*            STOP*  \
# 0  1/1/2016 21:11  1/1/2016 21:17  Business  Fort Pierce      Fort Pierce
# 1   1/2/2016 1:25   1/2/2016 1:37  Business  Fort Pierce      Fort Pierce
# 2  1/2/2016 20:25  1/2/2016 20:38  Business  Fort Pierce      Fort Pierce
# 3  1/5/2016 17:31  1/5/2016 17:45  Business  Fort Pierce      Fort Pierce
# 4  1/6/2016 14:42  1/6/2016 15:49  Business  Fort Pierce  West Palm Beach
#
#    MILES*         PURPOSE*
# 0     5.1   Meal/Entertain
# 1     5.0              NaN
# 2     4.8  Errand/Supplies
# 3     4.7          Meeting
# 4    63.7   Customer Visit

# %% [markdown]
# # Filtering

# %%
df[df["MILES*"]>10]
# Out:
#            START_DATE*         END_DATE* CATEGORY*            START*  \
# 4       1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# 9      1/10/2016 12:17   1/10/2016 12:44  Business           Jamaica
# 10     1/10/2016 15:08   1/10/2016 15:51  Business          New York
# 22     1/12/2016 16:02   1/12/2016 17:00  Business          New York
# 23     1/13/2016 13:54   1/13/2016 14:07  Business          Downtown
# ...                ...               ...       ...               ...
# 1134  12/29/2016 11:28  12/29/2016 12:00  Business  Unknown Location
# 1144  12/29/2016 23:14  12/29/2016 23:47  Business  Unknown Location
# 1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*        PURPOSE*
# 4      West Palm Beach     63.7  Customer Visit
# ...

# %%
df2=df.loc[df["MILES*"]>20,["START_DATE*","MILES*"]]

# %%
df2
# Out:
#            START_DATE*   MILES*
# 4       1/6/2016 14:42     63.7
# 25     1/14/2016 16:29     21.9
# 36     1/20/2016 13:25     40.2
# 62      2/1/2016 12:10     23.3
# 108     2/16/2016 3:21     43.7
# ...                ...      ...
# 1088  12/21/2016 20:56    103.0
# 1089  12/22/2016 15:40     32.3
# 1092  12/22/2016 17:56     23.2
# 1154  12/31/2016 22:08     48.2
# 1155            Totals  12204.7
#
# [84 rows x 2 columns]

# %% [markdown]
# # Find out all rides from New york

# %%
df4=df.loc[df["START*"]=="New York",["MILES*"]]

# %%
df4
# Out:
#      MILES*
# 10     10.8
# 22     15.1
# 106    13.0
# 423    16.3

# %%
df5=df.loc[df["START*"]=="New York",["PURPOSE*"]]

# %%
df5
# Out:
#     PURPOSE*
# 10   Meeting
# 22   Meeting
# 106  Meeting
# 423  Meeting

# %%
df6=df[df["START*"].isin(["Cary","New York"])]

# %%
df6
# Out:
#            START_DATE*         END_DATE* CATEGORY*    START*          STOP*  \
# 7       1/7/2016 13:27    1/7/2016 13:33  Business      Cary           Cary
# 8       1/10/2016 8:05    1/10/2016 8:25  Business      Cary    Morrisville
# 10     1/10/2016 15:08   1/10/2016 15:51  Business  New York         Queens
# 22     1/12/2016 16:02   1/12/2016 17:00  Business  New York  Queens County
# 28     1/15/2016 11:43   1/15/2016 12:03  Business      Cary         Durham
# ...                ...               ...       ...       ...            ...
# 1049  12/13/2016 20:20  12/13/2016 20:29  Business      Cary           Cary
# 1050  12/14/2016 16:52  12/14/2016 17:10  Business      Cary           Cary
# 1051  12/14/2016 17:22  12/14/2016 17:34  Business      Cary           Cary
# 1052  12/14/2016 17:50  12/14/2016 18:00  Business      Cary    Morrisville
# 1054  12/15/2016 14:20  12/15/2016 14:54  Business      Cary    Morrisville
#
#       MILES*        PURPOSE*
# ...

# %%
df.reset_index(inplace=True)

# %%
df
# Out:
#       index       START_DATE*         END_DATE* CATEGORY*            START*  \
# 0         0    1/1/2016 21:11    1/1/2016 21:17  Business       Fort Pierce
# 1         1     1/2/2016 1:25     1/2/2016 1:37  Business       Fort Pierce
# 2         2    1/2/2016 20:25    1/2/2016 20:38  Business       Fort Pierce
# 3         3    1/5/2016 17:31    1/5/2016 17:45  Business       Fort Pierce
# 4         4    1/6/2016 14:42    1/6/2016 15:49  Business       Fort Pierce
# ...     ...               ...               ...       ...               ...
# 1151   1151  12/31/2016 13:24  12/31/2016 13:42  Business           Kar?chi
# 1152   1152  12/31/2016 15:03  12/31/2016 15:38  Business  Unknown Location
# 1153   1153  12/31/2016 21:32  12/31/2016 21:50  Business        Katunayake
# 1154   1154  12/31/2016 22:08  12/31/2016 23:51  Business           Gampaha
# 1155   1155            Totals               NaN       NaN               NaN
#
#                  STOP*   MILES*         PURPOSE*
# ...

# %%
df7=df.loc[(df["MILES*"]>10) & (df["START*"].isin(["Cary","Morrisville"]))]

# %%
df7
# Out:
#       index       START_DATE*         END_DATE* CATEGORY* START*  \
# 28       28   1/15/2016 11:43   1/15/2016 12:03  Business   Cary
# 34       34   1/20/2016 10:36   1/20/2016 11:11  Business   Cary
# 46       46   1/27/2016 10:19   1/27/2016 10:48  Business   Cary
# 50       50   1/28/2016 12:28   1/28/2016 13:00  Business   Cary
# 55       55   1/29/2016 11:43   1/29/2016 12:03  Business   Cary
# ...     ...               ...               ...       ...    ...
# 990     990  11/22/2016 15:51  11/22/2016 16:43  Business   Cary
# 997     997  11/25/2016 11:47  11/25/2016 12:04  Business   Cary
# 1035   1035   12/9/2016 22:03   12/9/2016 22:57  Business   Cary
# 1036   1036  12/10/2016 12:43  12/10/2016 13:16  Business   Cary
# 1054   1054  12/15/2016 14:20  12/15/2016 14:54  Business   Cary
#
#               STOP*  MILES*        PURPOSE*
# 28           Durham    10.4  Meal/Entertain
# 34          Raleigh    17.1         Meeting
# 46          Raleigh    18.7  Customer Visit
# ...

# %%
df8=df7.reset_index(inplace=True,drop=True)
